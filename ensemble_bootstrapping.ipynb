# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split, stratified_kfold, cross_val_score

# %%
iris_df = sns.load_dataset('iris')
iris_df.head()
